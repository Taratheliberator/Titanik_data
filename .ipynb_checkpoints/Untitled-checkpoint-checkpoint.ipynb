# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd


titanic_data = pd.read_csv('titanic_data.csv')
titanic_surv = pd.read_csv('titanic_surv.csv')



titanic_data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic_surv.head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
titanic_combined = titanic_data.join(titanic_surv)

# %%
titanic_combined.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
dataset_description = titanic_combined.describe()

# %%
dataset_description
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
gender_distribution = titanic_combined['Sex'].value_counts()

# %%
gender_distribution
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
class_distribution = titanic_combined['Pclass'].value_counts().sort_index()

# %%
class_distribution
# Out:
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
male_survival_rate = titanic_combined[titanic_combined['Sex'] == 'male']['Survived'].mean()
female_survival_rate = titanic_combined[titanic_combined['Sex'] == 'female']['Survived'].mean()

male_survival_rate, female_survival_rate
# Out:
# (0.18890814558058924, 0.7420382165605095)

# %% [markdown]
# Доля выживших по полу:
#
# Мужчины: примерно 18.9%
# Женщины: примерно 74.2%
# Как видно, доля выживших женщин гораздо выше, чем у мужчин. Это может быть связано с приоритетом спасения женщин и детей в экстренных ситуациях.

# %%
labels = ['Мужчина', 'Женщина']
values = [male_survival_rate, female_survival_rate]


plt.figure(figsize=(8, 6))
plt.bar(labels, values, color=['blue', 'pink'])
plt.xlabel('Пол')
plt.ylabel('Коэффициент выживаемости')
plt.title('Уровень выживаемости по полу')
plt.ylim(0, 1)
plt.grid(axis='y')


plt.show()

# %% [markdown]
# Вот гистограмма распределения возрастов для выживших и не выживших пассажиров:
#
# Зеленый цвет показывает распределение возрастов среди выживших пассажиров.
# Красный цвет показывает распределение возрастов среди погибших пассажиров.
# Наблюдения:
#
# Дети в возрасте до 10 лет имели более высокий шанс на выживание по сравнению с другими возрастными группами.
# Большинство пассажиров в возрасте от 20 до 40 лет не выжили.

# %%
plt.figure(figsize=(12, 6))


plt.hist(titanic_combined[titanic_combined['Survived'] == 1]['Age'], 
         bins=30, alpha=0.5, label='Выжившие', color='green')


plt.hist(titanic_combined[titanic_combined['Survived'] == 0]['Age'], 
         bins=30, alpha=0.5, label='Невыжившие', color='red')

plt.title('Распределение возрастов выживших и невыживших пассажиров')
plt.xlabel('Возраст')
plt.ylabel('Количество пассажиров')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Гистограмма по классам кают для выживших и погибших пассажиров
plt.figure(figsize=(10, 6))

# Выжившие
plt.hist(titanic_combined[titanic_combined['Survived'] == 1]['Pclass'], 
         bins=np.arange(1, 5)-0.5, alpha=0.5, label='Survived', color='green', align='mid')

# Невыжившие
plt.hist(titanic_combined[titanic_combined['Survived'] == 0]['Pclass'], 
         bins=np.arange(1, 5)-0.5, alpha=0.5, label='Not Survived', color='red', align='mid')

plt.title('Распределение по классам кают для выживших и невыживших пассажиров')
plt.xlabel('Pclass')
plt.ylabel('Количество пассажиров')
plt.xticks([1, 2, 3])
plt.legend()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Наблюдения:
#
# Большинство пассажиров третьего класса не выжили.
# Пассажиры первого класса имели более высокий шанс на выживание по сравнению с пассажирами других классов.
# Таким образом, класс каюты и пол пассажира оказались важными факторами, которые повлияли на вероятность выживания на Титанике.

# %% [markdown]
# Заполнение пропусков в данных
# В данных имеются пропуски в трёх колонках:

# %%
titanic_combined.columns[titanic_combined.isna().any()].tolist()
# Out:
# ['Age', 'Cabin', 'Embarked']

# %%
titanic_combined.loc[:, ['Cabin', 'Embarked']] = titanic_combined.loc[:, ['Cabin', 'Embarked']].fillna('0')
titanic_combined['Age'] = titanic_combined['Age'].fillna(titanic_combined['Age'].median())

# %%
titanic_combined.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500     0        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250     0        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500     0        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
from sklearn.model_selection import train_test_split


titanic_combined_train, titanic_combined_test = train_test_split(titanic_combined, test_size=0.3, random_state=42)

titanic_combined_train.shape, titanic_combined_test.shape
# Out:
# ((623, 12), (268, 12))

# %%
titanic_encoded = pd.get_dummies(titanic_combined, columns=['Sex', 'Embarked'], drop_first=True)
titanic_encoded.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#     Age  SibSp  Parch            Ticket     Fare Cabin  Survived  Sex_male  \
# 0  22.0      1      0         A/5 21171   7.2500     0         0         1
# 1  38.0      1      0          PC 17599  71.2833   C85         1         0
# 2  26.0      0      0  STON/O2. 3101282   7.9250     0         1         0
# 3  35.0      1      0            113803  53.1000  C123         1         0
# 4  35.0      0      0            373450   8.0500     0         0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix



titanic_encoded_train, titanic_encoded_test = train_test_split(titanic_encoded, test_size=0.3, random_state=42)


X_train = titanic_encoded_train.drop("Survived", axis=1)


X_train = X_train.drop(columns=['Name', 'Ticket', 'Cabin'])
y_train = titanic_encoded_train["Survived"]

X_test = titanic_encoded_test.drop("Survived", axis=1)
X_test = X_test.drop(columns=['Name', 'Ticket', 'Cabin'])
y_test = titanic_encoded_test["Survived"]


logreg = LogisticRegression(max_iter=500)


logreg.fit(X_train, y_train)


y_pred = logreg.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)


report = classification_report(y_test, y_pred)

accuracy, report
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# (0.8059701492537313,
#  '              precision    recall  f1-score   support\n\n           0       0.82      0.86      0.84       157\n           1       0.79      0.73      0.76       111\n\n    accuracy                           0.81       268\n   macro avg       0.80      0.79      0.80       268\nweighted avg       0.81      0.81      0.80       268\n')

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt

# Predicting the probabilities of the test data
y_pred_prob = logreg.predict_proba(X_test)[:,1]

# Generating the ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Computing the AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plotting the ROC curve
plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# Инициализация модели Случайного леса
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# Обучение модели
random_forest.fit(X_train, y_train)

# Делаем предсказание
y_pred_rf = random_forest.predict(X_test)

# Рассчитываем точность
accuracy_rf = accuracy_score(y_test, y_pred_rf)

# Создаем отчет о классификации
report_rf = classification_report(y_test, y_pred_rf)

accuracy_rf, report_rf
# Out:
# (0.8134328358208955,
#  '              precision    recall  f1-score   support\n\n           0       0.80      0.90      0.85       157\n           1       0.84      0.68      0.75       111\n\n    accuracy                           0.81       268\n   macro avg       0.82      0.79      0.80       268\nweighted avg       0.82      0.81      0.81       268\n')

# %%
from sklearn.model_selection import GridSearchCV


logreg = LogisticRegression(max_iter=500)


param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}


grid_search = GridSearchCV(logreg, param_grid, cv=5, scoring='accuracy')


grid_search.fit(X_train, y_train)


best_C = grid_search.best_params_['C']


best_logreg = LogisticRegression(max_iter=500, C=best_C)
best_logreg.fit(X_train, y_train)


y_pred = best_logreg.predict(X_test)


best_accuracy = accuracy_score(y_test, y_pred)


best_C, best_accuracy
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV


rf = RandomForestClassifier(random_state=42)


param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30]
}


grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='accuracy')


grid_search.fit(X_train, y_train)


best_n_estimators = grid_search.best_params_['n_estimators']
best_max_depth = grid_search.best_params_['max_depth']


best_rf = RandomForestClassifier(n_estimators=best_n_estimators, max_depth=best_max_depth, random_state=42)
best_rf.fit(X_train, y_train)


y_pred = best_rf.predict(X_test)


best_accuracy = accuracy_score(y_test, y_pred)


best_n_estimators, best_max_depth, best_accuracy
# Out:
# (100, 10, 0.8059701492537313)

# %%
# Importing necessary libraries
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt


precision_rf = precision_score(y_test, y_pred)
recall_rf = recall_score(y_test, y_pred)
f1_rf = f1_score(y_test, y_pred)


y_prob_rf = best_rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf)
roc_auc_rf = roc_auc_score(y_test, y_prob_rf)


plt.figure(figsize=(10, 7))
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (AUC = {roc_auc_rf:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest')
plt.legend()
plt.show()

precision_rf, recall_rf, f1_rf, roc_auc_rf
# Out:
# (0.8390804597701149,
#  0.6576576576576577,
#  0.7373737373737375,
#  0.8705457049406093)
